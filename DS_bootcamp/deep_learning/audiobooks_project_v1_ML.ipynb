# %% [markdown]
# ### Audiobooks project - Machine Learning part

# %% [markdown]
# #### Problem
#
# You are given data from an Audiobook App. Logically, it relates to the audio versions of books ONLY. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertising to him/her. If we can focus our efforts SOLELY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, ), Book length overall (sum of the minute length of all purchases), Book length avg (average length in minutes of all purchases), Price paid_overall (sum of all purchases) ,Price Paid avg (average of all purchases), Review (a Boolean variable whether the customer left a review), Review out of 10 (if the customer left a review, his/her review out of 10, Total minutes listened, Completion (from 0 to 1), Support requests (number of support requests; everything from forgotten password to assistance for using the App), and Last visited minus purchase date (in days).
#
# These are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (0 or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.

# %%
# Importing libraries
import numpy as np
import tensorflow as tf

# %%
# Loading the data
npz = np.load('data/audiobooks_data_train_v1.npz')
train_inputs = npz['inputs'].astype(float)
train_targets = npz['targets'].astype(int)

npz = np.load('data/audiobooks_data_validation_v1.npz')
#We have to make sure that all inputs are floats and targets are int so we add .astype() to every each of them
validation_inputs = npz['inputs'].astype(float)
validation_targets = npz['targets'].astype(int)

npz = np.load('data/audiobooks_data_test_v1.npz')
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %% [markdown]
# ### NN Model

# %%
# The data is preprocessed in the proper way already so we don't have to use Flatten as the first layer as for example
# in the MNIST project.

input_size = 10 # 10 predictors
output_size = 2 # output is 0 or 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                             tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                             tf.keras.layers.Dense(hidden_layer_size, activation='softmax')
                            ])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# sparse_categorical_crossentropy applies one-hot encoding to the targets

batch_size = 100
max_epochs = 100

model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          validation_data=(validation_inputs, validation_targets),
          verbose=2)
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 3.2485 - accuracy: 0.4269 - val_loss: 2.2212 - val_accuracy: 0.6823
# Epoch 2/100
# 36/36 - 0s - loss: 1.2524 - accuracy: 0.7304 - val_loss: 0.6143 - val_accuracy: 0.7606
# Epoch 3/100
# 36/36 - 0s - loss: 0.5412 - accuracy: 0.7603 - val_loss: 0.4777 - val_accuracy: 0.7763
# Epoch 4/100
# 36/36 - 0s - loss: 0.4668 - accuracy: 0.7673 - val_loss: 0.4285 - val_accuracy: 0.7808
# Epoch 5/100
# 36/36 - 0s - loss: 0.4354 - accuracy: 0.7759 - val_loss: 0.4147 - val_accuracy: 0.7763
# Epoch 6/100
# 36/36 - 0s - loss: 0.4184 - accuracy: 0.7812 - val_loss: 0.3930 - val_accuracy: 0.7964
# Epoch 7/100
# 36/36 - 0s - loss: 0.4086 - accuracy: 0.7863 - val_loss: 0.3880 - val_accuracy: 0.7897
# Epoch 8/100
# 36/36 - 0s - loss: 0.3984 - accuracy: 0.7980 - val_loss: 0.3770 - val_accuracy: 0.7964
# Epoch 9/100
# 36/36 - 0s - loss: 0.3915 - accuracy: 0.7927 - val_loss: 0.3684 - val_accuracy: 0.7942
# Epoch 10/100
# 36/36 - 0s - loss: 0.3853 - accuracy: 0.7994 - val_loss: 0.3676 - val_accuracy: 0.7919
# Epoch 11/100
# 36/36 - 0s - loss: 0.3828 - accuracy: 0.8019 - val_loss: 0.3578 - val_accuracy: 0.8098
# Epoch 12/100
# 36/36 - 0s - loss: 0.3778 - accuracy: 0.8005 - val_loss: 0.3640 - val_accuracy: 0.7875
# Epoch 13/100
# 36/36 - 0s - loss: 0.3740 - accuracy: 0.7960 - val_loss: 0.3519 - val_accuracy: 0.8143
# Epoch 14/100
# 36/36 - 0s - loss: 0.3740 - accuracy: 0.8044 - val_loss: 0.3506 - val_accuracy: 0.8143
# Epoch 15/100
# 36/36 - 0s - loss: 0.3714 - accuracy: 0.7977 - val_loss: 0.3549 - val_accuracy: 0.8009
# Epoch 16/100
# 36/36 - 0s - loss: 0.3698 - accuracy: 0.7980 - val_loss: 0.3609 - val_accuracy: 0.8076
# Epoch 17/100
# 36/36 - 0s - loss: 0.3699 - accuracy: 0.8005 - val_loss: 0.3468 - val_accuracy: 0.8121
# Epoch 18/100
# 36/36 - 0s - loss: 0.3656 - accuracy: 0.8069 - val_loss: 0.3451 - val_accuracy: 0.8031
# Epoch 19/100
# 36/36 - 0s - loss: 0.3623 - accuracy: 0.8083 - val_loss: 0.3437 - val_accuracy: 0.8143
# Epoch 20/100
# 36/36 - 0s - loss: 0.3625 - accuracy: 0.8055 - val_loss: 0.3427 - val_accuracy: 0.8121
# Epoch 21/100
# 36/36 - 0s - loss: 0.3601 - accuracy: 0.8055 - val_loss: 0.3461 - val_accuracy: 0.8233
# Epoch 22/100
# 36/36 - 0s - loss: 0.3578 - accuracy: 0.8100 - val_loss: 0.3412 - val_accuracy: 0.8031
# Epoch 23/100
# 36/36 - 0s - loss: 0.3590 - accuracy: 0.8106 - val_loss: 0.3427 - val_accuracy: 0.8188
# Epoch 24/100
# 36/36 - 0s - loss: 0.3573 - accuracy: 0.8047 - val_loss: 0.3419 - val_accuracy: 0.8054
# Epoch 25/100
# 36/36 - 0s - loss: 0.3596 - accuracy: 0.8106 - val_loss: 0.3413 - val_accuracy: 0.8098
# Epoch 26/100
# 36/36 - 0s - loss: 0.3549 - accuracy: 0.8075 - val_loss: 0.3384 - val_accuracy: 0.8233
# Epoch 27/100
# 36/36 - 0s - loss: 0.3544 - accuracy: 0.8139 - val_loss: 0.3458 - val_accuracy: 0.8166
# Epoch 28/100
# 36/36 - 0s - loss: 0.3532 - accuracy: 0.8108 - val_loss: 0.3357 - val_accuracy: 0.8255
# Epoch 29/100
# 36/36 - 0s - loss: 0.3524 - accuracy: 0.8142 - val_loss: 0.3318 - val_accuracy: 0.8210
# Epoch 30/100
# 36/36 - 0s - loss: 0.3528 - accuracy: 0.8139 - val_loss: 0.3420 - val_accuracy: 0.8210
# Epoch 31/100
# 36/36 - 0s - loss: 0.3528 - accuracy: 0.8078 - val_loss: 0.3411 - val_accuracy: 0.8255
# Epoch 32/100
# 36/36 - 0s - loss: 0.3523 - accuracy: 0.8111 - val_loss: 0.3343 - val_accuracy: 0.8300
# Epoch 33/100
# 36/36 - 0s - loss: 0.3522 - accuracy: 0.8111 - val_loss: 0.3443 - val_accuracy: 0.8233
# Epoch 34/100
# 36/36 - 0s - loss: 0.3547 - accuracy: 0.8047 - val_loss: 0.3456 - val_accuracy: 0.8031
# Epoch 35/100
# 36/36 - 0s - loss: 0.3528 - accuracy: 0.8131 - val_loss: 0.3434 - val_accuracy: 0.8188
# Epoch 36/100
# 36/36 - 0s - loss: 0.3498 - accuracy: 0.8120 - val_loss: 0.3355 - val_accuracy: 0.8210
# Epoch 37/100
# 36/36 - 0s - loss: 0.3490 - accuracy: 0.8148 - val_loss: 0.3392 - val_accuracy: 0.8233
# Epoch 38/100
# 36/36 - 0s - loss: 0.3481 - accuracy: 0.8134 - val_loss: 0.3440 - val_accuracy: 0.8233
# Epoch 39/100
# 36/36 - 0s - loss: 0.3497 - accuracy: 0.8164 - val_loss: 0.3423 - val_accuracy: 0.8210
# Epoch 40/100
# 36/36 - 0s - loss: 0.3464 - accuracy: 0.8159 - val_loss: 0.3427 - val_accuracy: 0.7919
# Epoch 41/100
# 36/36 - 0s - loss: 0.3488 - accuracy: 0.8122 - val_loss: 0.3408 - val_accuracy: 0.8166
# Epoch 42/100
# 36/36 - 0s - loss: 0.3461 - accuracy: 0.8131 - val_loss: 0.3347 - val_accuracy: 0.8076
# Epoch 43/100
# 36/36 - 0s - loss: 0.3474 - accuracy: 0.8178 - val_loss: 0.3401 - val_accuracy: 0.8054
# Epoch 44/100
# 36/36 - 0s - loss: 0.3469 - accuracy: 0.8100 - val_loss: 0.3517 - val_accuracy: 0.8076
# Epoch 45/100
# 36/36 - 0s - loss: 0.3477 - accuracy: 0.8145 - val_loss: 0.3388 - val_accuracy: 0.8143
# Epoch 46/100
# 36/36 - 0s - loss: 0.3462 - accuracy: 0.8148 - val_loss: 0.3441 - val_accuracy: 0.8255
# Epoch 47/100
# 36/36 - 0s - loss: 0.3466 - accuracy: 0.8153 - val_loss: 0.3370 - val_accuracy: 0.8166
# Epoch 48/100
# 36/36 - 0s - loss: 0.3457 - accuracy: 0.8145 - val_loss: 0.3481 - val_accuracy: 0.8188
# Epoch 49/100
# 36/36 - 0s - loss: 0.3453 - accuracy: 0.8134 - val_loss: 0.3399 - val_accuracy: 0.8188
# Epoch 50/100
# 36/36 - 0s - loss: 0.3442 - accuracy: 0.8150 - val_loss: 0.3419 - val_accuracy: 0.8188
# Epoch 51/100
# 36/36 - 0s - loss: 0.3424 - accuracy: 0.8198 - val_loss: 0.3402 - val_accuracy: 0.8255
# Epoch 52/100
# 36/36 - 0s - loss: 0.3452 - accuracy: 0.8131 - val_loss: 0.3362 - val_accuracy: 0.8121
# Epoch 53/100
# 36/36 - 0s - loss: 0.3482 - accuracy: 0.8125 - val_loss: 0.3474 - val_accuracy: 0.8076
# Epoch 54/100
# 36/36 - 0s - loss: 0.3457 - accuracy: 0.8148 - val_loss: 0.3413 - val_accuracy: 0.8233
# Epoch 55/100
# 36/36 - 0s - loss: 0.3452 - accuracy: 0.8206 - val_loss: 0.3360 - val_accuracy: 0.8098
# Epoch 56/100
# 36/36 - 0s - loss: 0.3425 - accuracy: 0.8173 - val_loss: 0.3405 - val_accuracy: 0.8277
# Epoch 57/100
# 36/36 - 0s - loss: 0.3441 - accuracy: 0.8161 - val_loss: 0.3402 - val_accuracy: 0.8098
# Epoch 58/100
# 36/36 - 0s - loss: 0.3421 - accuracy: 0.8187 - val_loss: 0.3421 - val_accuracy: 0.8031
# Epoch 59/100
# 36/36 - 0s - loss: 0.3413 - accuracy: 0.8103 - val_loss: 0.3368 - val_accuracy: 0.8188
# Epoch 60/100
# 36/36 - 0s - loss: 0.3413 - accuracy: 0.8173 - val_loss: 0.3454 - val_accuracy: 0.8233
# Epoch 61/100
# 36/36 - 0s - loss: 0.3415 - accuracy: 0.8161 - val_loss: 0.3454 - val_accuracy: 0.8121
# Epoch 62/100
# 36/36 - 0s - loss: 0.3462 - accuracy: 0.8131 - val_loss: 0.3358 - val_accuracy: 0.8322
# Epoch 63/100
# 36/36 - 0s - loss: 0.3437 - accuracy: 0.8114 - val_loss: 0.3469 - val_accuracy: 0.8098
# Epoch 64/100
# 36/36 - 0s - loss: 0.3462 - accuracy: 0.8108 - val_loss: 0.3383 - val_accuracy: 0.8210
# Epoch 65/100
# 36/36 - 0s - loss: 0.3423 - accuracy: 0.8150 - val_loss: 0.3431 - val_accuracy: 0.8054
# Epoch 66/100
# 36/36 - 0s - loss: 0.3466 - accuracy: 0.8148 - val_loss: 0.3448 - val_accuracy: 0.8233
# Epoch 67/100
# 36/36 - 0s - loss: 0.3411 - accuracy: 0.8122 - val_loss: 0.3421 - val_accuracy: 0.8255
# Epoch 68/100
# 36/36 - 0s - loss: 0.3391 - accuracy: 0.8164 - val_loss: 0.3418 - val_accuracy: 0.8188
# Epoch 69/100
# 36/36 - 0s - loss: 0.3388 - accuracy: 0.8195 - val_loss: 0.3452 - val_accuracy: 0.8031
# Epoch 70/100
# 36/36 - 0s - loss: 0.3399 - accuracy: 0.8148 - val_loss: 0.3478 - val_accuracy: 0.8255
# Epoch 71/100
# 36/36 - 0s - loss: 0.3429 - accuracy: 0.8159 - val_loss: 0.3417 - val_accuracy: 0.8166
# Epoch 72/100
# 36/36 - 0s - loss: 0.3392 - accuracy: 0.8161 - val_loss: 0.3380 - val_accuracy: 0.8255
# Epoch 73/100
# 36/36 - 0s - loss: 0.3398 - accuracy: 0.8178 - val_loss: 0.3379 - val_accuracy: 0.8367
# Epoch 74/100
# 36/36 - 0s - loss: 0.3410 - accuracy: 0.8122 - val_loss: 0.3413 - val_accuracy: 0.8031
# Epoch 75/100
# 36/36 - 0s - loss: 0.3387 - accuracy: 0.8159 - val_loss: 0.3460 - val_accuracy: 0.8166
# Epoch 76/100
# 36/36 - 0s - loss: 0.3404 - accuracy: 0.8175 - val_loss: 0.3583 - val_accuracy: 0.7964
# Epoch 77/100
# 36/36 - 0s - loss: 0.3384 - accuracy: 0.8223 - val_loss: 0.3455 - val_accuracy: 0.8143
# Epoch 78/100
# 36/36 - 0s - loss: 0.3395 - accuracy: 0.8159 - val_loss: 0.3458 - val_accuracy: 0.8031
# Epoch 79/100
# 36/36 - 0s - loss: 0.3399 - accuracy: 0.8175 - val_loss: 0.3570 - val_accuracy: 0.7852
# Epoch 80/100
# 36/36 - 0s - loss: 0.3381 - accuracy: 0.8184 - val_loss: 0.3430 - val_accuracy: 0.8098
# Epoch 81/100
# 36/36 - 0s - loss: 0.3375 - accuracy: 0.8187 - val_loss: 0.3402 - val_accuracy: 0.8166
# Epoch 82/100
# 36/36 - 0s - loss: 0.3379 - accuracy: 0.8187 - val_loss: 0.3403 - val_accuracy: 0.8031
# Epoch 83/100
# 36/36 - 0s - loss: 0.3371 - accuracy: 0.8175 - val_loss: 0.3531 - val_accuracy: 0.8166
# Epoch 84/100
# 36/36 - 0s - loss: 0.3380 - accuracy: 0.8198 - val_loss: 0.3432 - val_accuracy: 0.8121
# Epoch 85/100
# 36/36 - 0s - loss: 0.3376 - accuracy: 0.8159 - val_loss: 0.3424 - val_accuracy: 0.8188
# Epoch 86/100
# 36/36 - 0s - loss: 0.3368 - accuracy: 0.8203 - val_loss: 0.3472 - val_accuracy: 0.8076
# Epoch 87/100
# 36/36 - 0s - loss: 0.3369 - accuracy: 0.8175 - val_loss: 0.3425 - val_accuracy: 0.8166
# Epoch 88/100
# 36/36 - 0s - loss: 0.3360 - accuracy: 0.8198 - val_loss: 0.3392 - val_accuracy: 0.8166
# Epoch 89/100
# 36/36 - 0s - loss: 0.3389 - accuracy: 0.8136 - val_loss: 0.3392 - val_accuracy: 0.8233
# Epoch 90/100
# 36/36 - 0s - loss: 0.3395 - accuracy: 0.8231 - val_loss: 0.3425 - val_accuracy: 0.8188
# Epoch 91/100
# 36/36 - 0s - loss: 0.3371 - accuracy: 0.8178 - val_loss: 0.3408 - val_accuracy: 0.8166
# Epoch 92/100
# 36/36 - 0s - loss: 0.3390 - accuracy: 0.8161 - val_loss: 0.3446 - val_accuracy: 0.8143
# Epoch 93/100
# 36/36 - 0s - loss: 0.3362 - accuracy: 0.8178 - val_loss: 0.3440 - val_accuracy: 0.8121
# Epoch 94/100
# 36/36 - 0s - loss: 0.3341 - accuracy: 0.8134 - val_loss: 0.3515 - val_accuracy: 0.8121
# Epoch 95/100
# 36/36 - 0s - loss: 0.3359 - accuracy: 0.8175 - val_loss: 0.3408 - val_accuracy: 0.8322
# Epoch 96/100
# 36/36 - 0s - loss: 0.3349 - accuracy: 0.8164 - val_loss: 0.3444 - val_accuracy: 0.8166
# Epoch 97/100
# 36/36 - 0s - loss: 0.3345 - accuracy: 0.8195 - val_loss: 0.3406 - val_accuracy: 0.8166
# Epoch 98/100
# 36/36 - 0s - loss: 0.3367 - accuracy: 0.8198 - val_loss: 0.3409 - val_accuracy: 0.8210
# Epoch 99/100
# 36/36 - 0s - loss: 0.3377 - accuracy: 0.8164 - val_loss: 0.3536 - val_accuracy: 0.8166
# Epoch 100/100
# 36/36 - 0s - loss: 0.3376 - accuracy: 0.8178 - val_loss: 0.3508 - val_accuracy: 0.8054

# %% [markdown]
# Even though the loss was mainly decreasing and we were getting higher accuracy which is good, the validation loss was decreasing at one time and increasing at some points. This shows us that our model was `overfitting`. At some point we should stop the model not to get overfitted.

# %%
# We can retrain the model using early_stopping callback
# I could just put it in the code above but this way there will be sth to compare it to...

input_size = 10 # 10 predictors
output_size = 2 # output is 0 or 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                             tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                             tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
                             tf.keras.layers.Dense(hidden_layer_size, activation='softmax')
                            ])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# sparse_categorical_crossentropy applies one-hot encoding to the targets

batch_size = 100
max_epochs = 100

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs,
          train_targets,
          batch_size = batch_size,
          epochs = max_epochs,
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets),
          verbose=2)
# Out:
# Epoch 1/100
# 36/36 - 1s - loss: 2.9223 - accuracy: 0.4739 - val_loss: 1.8570 - val_accuracy: 0.6689
# Epoch 2/100
# 36/36 - 0s - loss: 1.0958 - accuracy: 0.6764 - val_loss: 0.5869 - val_accuracy: 0.7651
# Epoch 3/100
# 36/36 - 0s - loss: 0.5246 - accuracy: 0.7578 - val_loss: 0.4618 - val_accuracy: 0.7606
# Epoch 4/100
# 36/36 - 0s - loss: 0.4563 - accuracy: 0.7709 - val_loss: 0.4224 - val_accuracy: 0.7852
# Epoch 5/100
# 36/36 - 0s - loss: 0.4291 - accuracy: 0.7793 - val_loss: 0.4035 - val_accuracy: 0.7897
# Epoch 6/100
# 36/36 - 0s - loss: 0.4132 - accuracy: 0.7835 - val_loss: 0.3871 - val_accuracy: 0.7875
# Epoch 7/100
# 36/36 - 0s - loss: 0.4030 - accuracy: 0.7893 - val_loss: 0.3720 - val_accuracy: 0.8031
# Epoch 8/100
# 36/36 - 0s - loss: 0.3941 - accuracy: 0.7918 - val_loss: 0.3690 - val_accuracy: 0.8098
# Epoch 9/100
# 36/36 - 0s - loss: 0.3877 - accuracy: 0.7949 - val_loss: 0.3634 - val_accuracy: 0.7987
# Epoch 10/100
# 36/36 - 0s - loss: 0.3830 - accuracy: 0.7974 - val_loss: 0.3562 - val_accuracy: 0.8054
# Epoch 11/100
# 36/36 - 0s - loss: 0.3783 - accuracy: 0.8025 - val_loss: 0.3537 - val_accuracy: 0.7987
# Epoch 12/100
# 36/36 - 0s - loss: 0.3747 - accuracy: 0.8058 - val_loss: 0.3522 - val_accuracy: 0.8031
# Epoch 13/100
# 36/36 - 0s - loss: 0.3710 - accuracy: 0.8036 - val_loss: 0.3473 - val_accuracy: 0.8076
# Epoch 14/100
# 36/36 - 0s - loss: 0.3672 - accuracy: 0.8058 - val_loss: 0.3521 - val_accuracy: 0.7964
# Epoch 15/100
# 36/36 - 0s - loss: 0.3652 - accuracy: 0.8108 - val_loss: 0.3416 - val_accuracy: 0.8143
# Epoch 16/100
# 36/36 - 0s - loss: 0.3632 - accuracy: 0.8103 - val_loss: 0.3510 - val_accuracy: 0.8009
# Epoch 17/100
# 36/36 - 0s - loss: 0.3643 - accuracy: 0.8092 - val_loss: 0.3444 - val_accuracy: 0.8121

# %% [markdown]
# ### Testing the model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8103

# %%
print('Test loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100))
# Out:
# Test loss: 0.36. Test accuracy: 81.03%
